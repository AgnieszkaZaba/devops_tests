# %% [markdown]
# This is a deliberately failing notebook for tests: it contains two failing patterns
# - a code cell missing the execution_count key (should trigger `Cell does not contain output!` / jetbrains check)
# - a stderr output (should trigger `test_no_errors_or_warnings_in_output` if reached)

# %%
print('this cell lacks the execution_count key')

# %%
import sys
print('error to stderr', file=sys.stderr)
# Out:
# Example error on stderr
